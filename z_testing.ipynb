# %%
from src import data_gen
from src import simulation
from src import visualizations
# Out:
# /Users/Lisa/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/Lisa/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /Users/Lisa/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from src import simulation
import datetime

# %%
deck_loc = data_gen.save_decks(100, filepath = "data")

# %%
results, n_games, all_wins = simulation.simulate_games(deck_path = 'data/decks_20250323112757.npy')

# %%
print(deck_loc)

# %%
import pandas as pd
results = pd.read_csv('data/results_n_10000000_20250324012220.csv',index_col=0)
results
# Out:
#    player_1_seq player_2_seq  player_1_wins_cards  ties_cards  \
# 0     [1, 1, 1]    [1, 1, 1]                  NaN         NaN
# 0     [1, 1, 1]    [1, 1, 0]            4715722.0    193387.0
# 0     [1, 1, 1]    [1, 0, 1]            2799188.0    160108.0
# 0     [1, 1, 1]    [1, 0, 0]            1876650.0    195256.0
# 0     [1, 1, 1]    [0, 1, 1]                303.0       104.0
# ..          ...          ...                  ...         ...
# 0     [0, 0, 0]    [1, 0, 0]                328.0        90.0
# 0     [0, 0, 0]    [0, 1, 1]            1876565.0    194786.0
# 0     [0, 0, 0]    [0, 1, 0]            2797812.0    158493.0
# 0     [0, 0, 0]    [0, 0, 1]            4715591.0    194093.0
# 0     [0, 0, 0]    [0, 0, 0]                  NaN         NaN
#
#     player_1_wins_tricks  ties_tricks
# 0                    NaN          NaN
# 0              4094354.0    1571245.0
# 0              2207413.0    1279238.0
# 0              1324148.0    1281915.0
# ...

# %%
visualizations.make_plot(results, 10000000, filename = 'results.png')

# %%
from src import data_gen
from src import simulation
from src import visualizations

import pandas as pd
import json

#add 10000 new decks (if you made your own new decks, use the most recent state)
new_deck_loc = data_gen.save_decks(10000, seed_path = 'state_20250323214955.json', filepath = "data")

#read in old wins and results
old_results = pd.read_csv('data/results_n_10000000_20250324012220.csv')
with open('data/wins_n_10000000_20250324012221.json','r') as file:
    old_wins = json.load(file)

results, n_games, all_wins = simulation.add_decks(old_wins, old_results, new_deck_loc, 10000000)


#make plot
visualizations.make_plot(results, n_games, filename = 'more_results.png')
# Out:
# /Users/Lisa/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/Lisa/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /Users/Lisa/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ...
